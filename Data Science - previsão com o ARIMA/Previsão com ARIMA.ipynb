# %% [markdown]
# # Data Science - Previsão com ARIMA

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.tsa.api as smtsa
import numpy as np

# %% [markdown]
# ## Importando os dados

# %%
dados_ar1 = pd.read_csv('produto_ar1.csv')
dados_ar2 = pd.read_csv('produto_ar2.csv')
dados_ar3 = pd.read_csv('produto_ar3.csv')

# %% [markdown]
# ## Visualizando os dados

# %%
# dados 1
plt.figure(figsize=(12,8))
plt.plot(dados_ar1['Data'], dados_ar1['Preco'])
plt.xlabel('Data')
plt.ylabel('Preco')
# Out:
# Text(0, 0.5, 'Preco')

# %% [markdown]
# ### Ver o comportamento de auto correlação e autocorrelação parcial

# %%
plot_acf(dados_ar1['Preco']);

# %% [markdown]
# Preceber que o decaimento é suave na auto correlação

# %%
plot_pacf(dados_ar1['Preco']);

# %% [markdown]
# ### Na autocorrelação parcial o decaimento é abrupto depois do primeiro lag,
# ### Esse é um modelo autoregressivo de ordem 1

# %% [markdown]
# ---

# %%
# dados 2
plt.figure(figsize=(12,8))
plt.plot(dados_ar1['Data'], dados_ar2['Preco'])
plt.xlabel('Data')
plt.ylabel('Preco')
# Out:
# Text(0, 0.5, 'Preco')

# %%
plot_acf(dados_ar2['Preco']);

# %%
plot_pacf(dados_ar2['Preco']);

# %% [markdown]
# ### Na autocorrelação parcial o decaimento é abrupto depois do segundo lag,
# ### Esse é um modelo autoregressivo de ordem 2

# %% [markdown]
# ---

# %%
# dados 3
plt.figure(figsize=(12,8))
plt.plot(dados_ar1['Data'], dados_ar3['Preco'])
plt.xlabel('Data')
plt.ylabel('Preco')
# Out:
# Text(0, 0.5, 'Preco')

# %%
plot_acf(dados_ar3['Preco']);

# %%
plot_pacf(dados_ar3['Preco']);

# %% [markdown]
# ### Na autocorrelação parcial o decaimento é abrupto depois do terceiro lag,
# ### Esse é um modelo autoregressivo de ordem 3

# %% [markdown]
# ---

# %% [markdown]
# ## Ajuste dos modelos Autocorrelacionados - AR

# %% [markdown]
# ### Divisão dos dados para treino e teste
# #### Ordem 1

# %%
dados_ar1_p1 = dados_ar1[0:500]
dados_ar1_p2 = dados_ar1[500:600]

# %%
modelo_ar1 = smtsa.ARMA(dados_ar1_p1['Preco'], order=(1, 0)).fit()
# Out:
# C:\Users\dudu_\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
modelo_previsto1 = modelo_ar1.predict(start=500,end=599)

# %%
plt.figure(figsize=(12,8))
plt.plot(dados_ar1_p1['Data'],dados_ar1_p1['Preco'])
plt.plot(dados_ar1_p2['Data'],dados_ar1_p2['Preco'])
plt.plot(dados_ar1_p2['Data'], modelo_previsto1,'r.')

# %% [markdown]
# #### Ordem 2

# %%
dados_ar2_p1 = dados_ar2[0:500]
dados_ar2_p2 = dados_ar2[500:600]

# %%
modelo_ar2 = smtsa.ARMA(dados_ar2_p1['Preco'], order=(2, 0)).fit()
# Out:
# C:\Users\dudu_\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
modelo_previsto2 = modelo_ar2.predict(start=500,end=599)

# %%
# somente o trecho a ser previsto:
plt.figure(figsize=(12,8))
plt.plot(dados_ar2_p2['Data'],dados_ar2_p2['Preco'])
plt.plot(dados_ar2_p2['Data'], modelo_previsto2,'r.')

# %% [markdown]
# #### Ordem 3

# %%
dados_ar3_p1 = dados_ar3[0:500]
dados_ar3_p2 = dados_ar3[500:600]

modelo_ar3 = smtsa.ARMA(dados_ar3_p1['Preco'], order=(3, 0)).fit()

modelo_previsto3 = modelo_ar3.predict(start=500,end=599)
# Out:
# C:\Users\dudu_\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
# somente o trecho a ser previsto:
plt.figure(figsize=(12,8))
plt.plot(dados_ar3_p2['Data'],dados_ar3_p2['Preco'])
plt.plot(dados_ar3_p2['Data'], modelo_previsto3,'r.')

# %% [markdown]
#  ---

# %% [markdown]
# ## Modelo de Média Móvel - MA

# %%
dado_ma1 = pd.read_csv('produto_ma1.csv')

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_ma1['Data'],dado_ma1['Preco'])

# %%
plot_acf(dado_ma1['Preco']);

# %%
plot_pacf(dado_ma1['Preco']);

# %% [markdown]
# #### Diferentemente do modelo AR o modelo de MA o autocorrelacionamento que muda abruptamente é o parcial

# %%
dado_ma1_p1 = dado_ma1[0:500]
dado_ma1_p2 = dado_ma1[500:600]

# %%
modelo_ma1 = smtsa.ARMA(dado_ma1_p1['Preco'], order=(0, 1)).fit()
modelo_previsto_ma1 = modelo_ma1.predict(start=500,end=599)
# Out:
# C:\Users\dudu_\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_ma1_p2['Data'],dado_ma1_p2['Preco'])
plt.plot(dado_ma1_p2['Data'], modelo_previsto_ma1,'.r')

# %% [markdown]
# ---

# %%
dado_ma3 = pd.read_csv('produto_ma3.csv')

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_ma3['Data'],dado_ma3['Preco'])

# %%
plot_acf(dado_ma3['Preco']);

# %%
plot_pacf(dado_ma3['Preco']);

# %%
dado_ma3_p1 = dado_ma3[0:500]
dado_ma3_p2 = dado_ma3[500:600]

# %%
modelo_ma3 = smtsa.ARMA(dado_ma3_p1['Preco'], order=(0, 3)).fit()
# Out:
# C:\Users\dudu_\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
modelo_previsto_ma3 = modelo_ma3.predict(start=500,end=599)

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_ma3_p2['Data'],dado_ma3_p2['Preco'])
plt.plot(dado_ma3_p2['Data'], modelo_previsto_ma3,'r.')

# %% [markdown]
# ---

# %% [markdown]
# ## Modelo misto, Autocorrelacionado e média móvel - ARMA

# %%
dado_arma1 = pd.read_csv('produto_arma1_1.csv')

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_arma1['Data'],dado_arma1['Preco'])

# %%
plot_acf(dado_arma1['Preco']);

# %%
plot_pacf(dado_arma1['Preco']);

# %% [markdown]
# #### Podemos perceber que há um pouco dos 2 nos gráficos

# %%
dado_arma1_p1 = dado_arma1[0:500]
dado_arma1_p2 = dado_arma1[500:600]

# %%
modelo_arma1 = smtsa.ARMA(dado_arma1_p1['Preco'], order=(1, 1)).fit()
# Out:
# C:\Users\dudu_\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
modelo_previsto_arma1 = modelo_arma1.predict(start=500,end=599)

# %%
plt.figure(figsize=(12,8))
plt.plot(dado_arma1_p2['Data'],dado_arma1_p2['Preco'])
plt.plot(dado_arma1_p2['Data'], modelo_previsto_arma1,'r')

# %% [markdown]
# ---

# %% [markdown]
# # Previsão e estacionariedade

# %%
cresc = pd.read_csv('produto_crescente.csv')

# %%
plt.figure(figsize=(12,5))
plt.plot(cresc['Data'],cresc['Preco'])
plt.xticks(rotation=70);

# %%
plot_acf(cresc['Preco']);

# %%
plot_pacf(cresc['Preco']);

# %%
cresc.shape
# Out:
# (36, 2)

# %%
cresc_p1 = cresc[:26][:]
cresc_p2 = cresc[26:][:]

# %%
modelo_cresc = smtsa.ARMA(cresc_p1['Preco'].values, order=(1, 2)).fit();
# Out:
# C:\Users\dudu_\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
modelo_previsto_cresc = modelo_cresc.predict(start=26,end=35)

# %%
plt.figure(figsize=(12,5))
plt.plot(cresc_p1['Data'],cresc_p1['Preco'])
plt.plot(cresc_p1['Data'],modelo_cresc.fittedvalues,'.')
plt.plot(cresc_p2['Data'],cresc_p2['Preco'])
plt.plot(cresc_p2['Data'],modelo_previsto_cresc,'r.')
plt.xticks(rotation=70);

# %% [markdown]
# ### O método ARMA assume que a série temporal é estacionária

# %% [markdown]
# ---

# %% [markdown]
# ### O modelo que melhor se adapta é o ARIMA, onde há a manipulação dos dados fazendo a diferenciação dos dados para que fiquem estacionários

# %%
cresc_d = cresc['Preco'].diff(1)

# %%
plt.figure(figsize=(12,5))
plt.plot(cresc['Data'], cresc_d)
plt.xticks(rotation=70);

# %% [markdown]
# ## Aplicação do Modelo ARIMA

# %%
modelo_cresc = smtsa.ARIMA(cresc_p1['Preco'].values, order=(1,1,2)).fit()
# valores do order são chutados
# Out:
# C:\Users\dudu_\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
modelo_cresc.plot_predict(26,35);
plt.plot(np.linspace(0,9,10),cresc_p2['Preco'])

# %% [markdown]
# ## Auto ARIMA

# %%
# !pip install pmdarima

# %%
from pmdarima.arima import auto_arima

# %%
modelo_busca = auto_arima(cresc_p1['Preco'].values,start_p=0, start_q=0, 
                            max_p=6, max_q=6, d=1,seasonal=False, trace=True,
                            error_action='ignore', suppress_warnings=True, stepwise=False)
# Out:
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=68.674, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.10 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=55.616, Time=0.07 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=57.534, Time=0.07 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=57.274, Time=0.07 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=57.267, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=55.729, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=56.233, Time=0.14 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=57.982, Time=0.11 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=58.874, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=57.593, Time=0.07 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=58.225, Time=0.11 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.21 sec
# ...

# %% [markdown]
# ### Nesse caso usamos o fator d (diferenciação) fixo com o valor 1

# %%
modelo_busca.aic()
# melhor valor de combinação para os parâmetros do order
# Out:
# 54.490349275345515

# %% [markdown]
# ### O procedimento de auto ARIMA já montou o modelo com a melhor combinação dos parâmetros order

# %%
modelo_busca.fit(cresc_p1['Preco'].values)
# Out:
# ARIMA(order=(3, 1, 0), scoring_args={}, suppress_warnings=True)

# %%
valores_preditos = modelo_busca.predict(n_periods=10)

# %%
plt.plot(cresc_p2['Data'],valores_preditos, color='r')
plt.plot(cresc_p2['Data'],cresc_p2['Preco'], color='b')

# %% [markdown]
# ---

# %% [markdown]
# ## Modelos com Sazonalidade - SARIMA

# %%
from pmdarima.arima.utils import nsdiffs

# %% [markdown]
# #### Método para obtenção do valor do D para o modelo SARIMA

# %%
D = nsdiffs(cresc_p1['Preco'].values, m=2, max_D=12, test='ch')

# %%
D
# Out:
# 1

# %% [markdown]
# #### Observar que o D está no modelo

# %%
modelo_busca2 = auto_arima(cresc_p1['Preco'].values,start_p=0, start_q=0, max_p=6, max_q=6, d=1,D=1,
                            start_Q=1, start_P=1,
                            max_P=4, max_Q=4,m=2, seasonal=True, trace=True, error_action='ignore',
                            suppress_warnings=True, stepwise=False, maxiter=50)
# Out:
#  ARIMA(0,1,0)(0,1,0)[2]             : AIC=67.164, Time=0.02 sec
#  ARIMA(0,1,0)(0,1,1)[2]             : AIC=62.597, Time=0.02 sec
#  ARIMA(0,1,0)(0,1,2)[2]             : AIC=64.342, Time=0.03 sec
#  ARIMA(0,1,0)(0,1,3)[2]             : AIC=65.503, Time=0.04 sec
#  ARIMA(0,1,0)(0,1,4)[2]             : AIC=inf, Time=0.17 sec
#  ARIMA(0,1,0)(1,1,0)[2]             : AIC=62.177, Time=0.02 sec
#  ARIMA(0,1,0)(1,1,1)[2]             : AIC=64.071, Time=0.03 sec
#  ARIMA(0,1,0)(1,1,2)[2]             : AIC=65.965, Time=0.04 sec
#  ARIMA(0,1,0)(1,1,3)[2]             : AIC=66.807, Time=0.09 sec
#  ARIMA(0,1,0)(1,1,4)[2]             : AIC=inf, Time=0.18 sec
#  ARIMA(0,1,0)(2,1,0)[2]             : AIC=64.110, Time=0.02 sec
#  ARIMA(0,1,0)(2,1,1)[2]             : AIC=inf, Time=0.13 sec
#  ARIMA(0,1,0)(2,1,2)[2]             : AIC=67.768, Time=0.08 sec
#  ARIMA(0,1,0)(2,1,3)[2]             : AIC=inf, Time=0.25 sec
#  ARIMA(0,1,0)(3,1,0)[2]             : AIC=66.030, Time=0.04 sec
# ...

# %% [markdown]
# ### O modelo anterior sem a sazonalidade

# %%
modelo_busca.aic()
# Out:
# 54.490349275345515

# %% [markdown]
# ### O novo modelo com a sazonalidade

# %%
modelo_busca2.aic()
# Out:
# 48.26628065593672

# %% [markdown]
# #### Quanto menor o valor, melhor

# %%
modelo_busca2.fit(cresc_p1['Preco'].values)
# Out:
# ARIMA(order=(1, 1, 0), scoring_args={}, seasonal_order=(4, 1, 0, 2),
#       suppress_warnings=True, with_intercept=False)

# %%
valores_preditos2 = modelo_busca2.predict(n_periods=10)

# %%
plt.plot(valores_preditos2, color='r')
plt.plot(np.linspace(0,9,10),cresc_p2['Preco'], color='b')

# %% [markdown]
# ## Acrescentado valores e retrinado o modelo

# %%
from pmdarima.datasets import load_lynx

# %%
dado_lynx = load_lynx()

# %%
dado_lynx.shape
# Out:
# (114,)

# %%
from pmdarima import model_selection

# %%
treino, teste = model_selection.train_test_split(dado_lynx, train_size=100)

# %%
teste1 = teste[:10]
teste2 = teste[10:]

# %%
modelo_arima = auto_arima(treino, start_p=1, start_q=1, d=0, max_p=5, max_q=5,
                          suppress_warnings=True, stepwise=True, error_action='ignore')

# %%
previsoes = modelo_arima.predict(n_periods=teste1.shape[0])

# %%
plt.plot(np.arange(0,treino.shape[0]),treino)
plt.plot(np.arange(treino.shape[0],treino.shape[0] + teste1.shape[0]),teste1)
plt.plot(np.arange(treino.shape[0],treino.shape[0] + teste1.shape[0]),previsoes)

# %% [markdown]
# ## Retreinando

# %%
modelo_arima.update(teste1)
# Out:
# ARIMA(order=(2, 0, 0), scoring_args={}, suppress_warnings=True)

# %%
novas_pred = modelo_arima.predict(n_periods=teste2.shape[0])

# %%
plt.plot(np.arange(0, treino.shape[0]), treino)
plt.plot(np.arange(treino.shape[0], treino.shape[0] + teste1.shape[0]), teste1)
plt.plot(np.arange(treino.shape[0] + teste1.shape[0],treino.shape[0] + teste1.shape[0] + teste2.shape[0]), teste2)
plt.plot(np.arange(treino.shape[0] + teste1.shape[0],treino.shape[0] + teste1.shape[0] + teste2.shape[0]), novas_pred)

# %% [markdown]
# ## Salvando o modelo

# %%
import joblib

# %%
joblib.dump(modelo_busca2,'sarima.pkl')
# Out:
# ['sarima.pkl']

# %% [markdown]
# ## Carregando um modelo salvo e já prevendo

# %%
previsao_joblib = joblib.load('sarima.pkl').predict(n_periods=10)

# %% [markdown]
# ### Comparação para provar que o modelo continua o mesmo

# %%
np.allclose(valores_preditos2,previsao_joblib)
# Out:
# True
